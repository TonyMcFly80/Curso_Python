# %% [markdown]
# #REPRESENTACIÓN GRÁFICA EN PYTHON

# %% [markdown]
# *Examen que tuve que realizar para completar con exito este tema perteneciente al curso de Python.*

# %% [markdown]
# **NOTA:** No es necesario usar código para comprobar si los datos introducidos por el usuario son correctos. Vamos a interpretar que así es por ahora a menos que se especifique lo contrario.

# %% [markdown]
# # EXAMEN

# %% [markdown]
# **EJERCICIO 01**

# %% [markdown]
# Dibuja 100 puntos aleatorios (entre 0 y 100 para ambas coordenadas) con colores y tamaños aleatorios y una transparencia de 0.5.
#
# Tendrás que crear 4 arrays aleatorios de 100 posiciones: uno para las coordenadas x, otro para y, otro para el color de cada punto y un último para el tamaño de cada punto. Para que los puntos no se vean muy pequeños, multiplica el array de tamaños por 10.
#
# Configura el tamaño de la figure a 10 x 10. Para ello, investiga el método .figure() de plt.
#
# Por último, selecciona los colores combinando el array aleatorio y el mapa de color llamado hsv. Recuerda mostrar la colorbar.

# %%
import matplotlib.pyplot as plt
from numpy import random

x = random.randint(101, size=100)
y = random.randint(101, size=100)
color = random.randint(101, size=100)
tam = random.randint(101, size=100) * 10

plt.title('Puntos Aleatorios')
plt.xlabel('Coordenadas X')
plt.ylabel('Coordenadas Y')

plt.scatter(x=x, y=y, c=color, cmap='hsv', marker='.', s=tam, alpha=0.5)

plt.figure(num=1, figsize=(10, 10))
plt.colorbar()
plt.show()

# %% [markdown]
# ![Figure_1.png](data:image/png;base64,...)

# %% [markdown]
# **EJERCICIO 02**

# %% [markdown]
# En el plano complejo, representa los números complejos 1 + i, 2i, −1 − i, −3, −2 − i, −2i y 1 − i.
#
# Recuerda que el plano complejo es como un plano cartesiano, salvo que el eje horizontal se denomina eje real y, el eje vertical, eje imaginario.
#
# Representa los puntos de color rojo y tamaño 120 y los ejes vertical y horizontal de color negro y transparencia 0.5. Para representar los puntos, puedes considerar una lista que contenga las partes reales y otra lista que contenga las partes imaginarias de los números complejos. Para representar los ejes, debes dibujar una recta horizontal y = 0 y otra vertical x = 0. Investiga para ello el método .linspace() de numpy. Para que las dimensiones del argumento x e y sean las mismas, puede que tengas que usar el método .zeros de numpy para obtener un array de ceros del tamaño deseado.
#
# Pon como título “Plano complejo” e investiga los métodos .xlim e .ylim de plt para establecer el rango de x en el intervalo [-3.2, 3.2] y el rango de y en el intervalo [-2.2, 2.2].

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.title('PLANO COMPLEJO')

x_real = [1, 0, -1, -3, -2, 0, 1]
y_img = [1, 2, -1, 0, -1, -2, -1]

x = np.linspace(-3.2, 3.2, 100)
y = np.linspace(-2.2, 2.2, 100)

plt.plot(x, np.zeros(100), c='k', alpha=0.5)
plt.plot(y, np.zeros(100), c='k', alpha=0.5)

plt.scatter(x=x_real, y=y_img, c='r', s=120)

plt.xlim([-3.2, 3.2])
plt.ylim([-2.2, 2.2])

plt.show()

# %% [markdown]
# ![Figure_2.png](data:image/png;base64,...)

# %% [markdown]
# **EJERCICIO 03**

# %% [markdown]
# Crea una función que dado un color en forma RGB lo transforme en su forma hexadecimal.

# %%
def rgb_to_hex(r, g, b):
    """
    Pasa un color en formato RGB a Hexadecimal.
    :param r: Código de Rojo.
    :param g: Código de Verde.
    :param b: Código de Azul.
    :return: El hexadecimal de RGB introducido
    """
    return f'#{r:02x}{g:02x}{b:02x}'


print(rgb_to_hex(255, 255, 195))

# %% [markdown]
# **EJERCICIO 04**

# %% [markdown]
# ![Sin título1.png](data:image/png;base64,...)

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

arr_x = np.linspace(-5 * math.pi, 5 * math.pi, 100)

plt.figure(num=1, figsize=(8, 6))
plt.plot(arr_x, np.sin(arr_x) / arr_x, c='#F06741')
plt.plot(arr_x, 2 * np.sin(arr_x) / arr_x, c='#A4F041')
plt.plot(arr_x, -(np.sin(arr_x) / arr_x), c='#8D41F0')

plt.show()

# %% [markdown]
# ![Figure_4.png](data:image/png;base64,...)

# %% [markdown]
# **EJERCICIO 05**

# %% [markdown]
# Dibuja las 3 funciones del ejercicio anterior cada una en un subplot con el método .subplot().
#
# Haz que el tamaño de la figure global sea 10 x 5.

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

arr_x = np.linspace(-5 * math.pi, 5 * math.pi, 100)

plt.figure(num=1, figsize=(10, 5))

plt.subplot(3, 1, 1)
plt.plot(arr_x, np.sin(arr_x) / arr_x, c='#F06741')

plt.subplot(3, 1, 2)
plt.plot(arr_x, 2 * np.sin(arr_x) / arr_x, c='#A4F041')

plt.subplot(3, 1, 3)
plt.plot(arr_x, -(np.sin(arr_x) / arr_x), c='#8D41F0')

plt.show()

# %% [markdown]
# ![Figure_5.png](data:image/png;base64,...)

# %% [markdown]
# **EJERCICIO 06**

# %% [markdown]
# Dibuja un diagrama de sectores con los siguientes datos y los siguientes colores. Añádele un título, etiquetas,
# sombra, una separación de 0.2 al sector más pequeño, haz que empiece en el ángulo 45 y muestra los porcentajes con un solo decimal.
#
# options = ["Suspenso", "Aprobado", "Notable", "Excelente"]
#
# count = [20, 10, 45, 25]
#
# colors = ["#ff2667", "#ff7226", "#26a8ff", "#67ff26"]

# %%
import matplotlib.pyplot as plt


options = ["Suspenso", "Aprobado", "Notable", "Excelente"]
count = [20, 10, 45, 25]
colors = ["#FF2667", "#FF7226", "#26A8FF", "#67FF26"]

plt.pie(count, colors=colors, labels=options, startangle=45, autopct='%0.1f%%',
        shadow=True, explode=[0, 0.2, 0, 0])

plt.legend(title='Notas')
plt.title('Evaluaciones')

plt.show()

# %% [markdown]
# ![Figure_6.png](data:image/png;base64,...)

# %% [markdown]
# **EJERCICIO 07**

# %% [markdown]
# Dibuja el siguiente grafo con los nodos de color #ad80fa, las aristas de color #b1ddf5, el nombre de los nodos de color blanco y en negrita.
#
# import networkx as nx
#
# G = nx.Graph()
#
# G.add_nodes_from("abcde")
#
# G.add_weighted_edges_from([("a", "b", 1), ("a", "c", 2), ("a", "d", 2), ("a", "e", 5), ("b", "e", 4), ("c", "d", 3), ("d", "e", 1)])

# %%
import matplotlib.pyplot as plt
import networkx as nx

G = nx.Graph()
G.add_nodes_from("abcde")
G.add_weighted_edges_from([("a", "b", 1), ("a", "c", 2), ("a", "d", 2), ("a", "e", 5),
                           ("b", "e", 4), ("c", "d", 3), ("d", "e", 1)])

nx.draw(G=G, with_labels=True, node_color='#AD80FA', edge_color='#B1DDF5',
        font_color='white', font_weight='bold')

plt.show()

# %% [markdown]
# ![Figure_7.png](data:image/png;base64,...)

# %% [markdown]
# **EJERCICIO 08**

# %% [markdown]
# Considera el grafo del ejercicio anterior. El tamaño de los nodos debe ser 350 por el grado del nodo. El tamaño de la figure global debe ser de 8 x 6.

# %%
import matplotlib.pyplot as plt
import networkx as nx

G = nx.Graph()
G.add_nodes_from("abcde")
G.add_weighted_edges_from([("a", "b", 1), ("a", "c", 2), ("a", "d", 2), ("a", "e", 5),
                           ("b", "e", 4), ("c", "d", 3), ("d", "e", 1)])

plt.figure(figsize=(8, 6))
nx.draw(G=G, with_labels=True, node_color='#AD80FA', edge_color='#B1DDF5',
        font_color='white', font_weight='bold', node_size=[350 * G.degree(n) for n in G.nodes])

plt.show()

# %% [markdown]
# ![Figure_8.png](data:image/png;base64,...)

# %% [markdown]
# **EJERCICIO 09**

# %% [markdown]
# Considera el grafo del ejercicio anterior. El grosor de las aristas debe ir acorde al peso de cada arista.

# %%
import matplotlib.pyplot as plt
import networkx as nx

G = nx.Graph()
G.add_nodes_from("abcde")
G.add_weighted_edges_from([("a", "b", 1), ("a", "c", 2), ("a", "d", 2), ("a", "e", 5),
                           ("b", "e", 4), ("c", "d", 3), ("d", "e", 1)])

plt.figure(figsize=(8, 6))
nx.draw(G=G, with_labels=True, node_color='#AD80FA', edge_color='#B1DDF5',
        font_color='white', font_weight='bold', node_size=[350 * G.degree(n) for n in G.nodes],
        width=[G[i][j]['weight'] for i, j in G.edges])

plt.show()

# %% [markdown]
# ![Figure_9.png](data:image/png;base64,...)

# %% [markdown]
# **EJERCICIO 10**

# %% [markdown]
# Investiga el método .text() de plt para añadir texto a los plots.
#
# Añade las siguientes 3 palabras “LA”, “AVENTURA”, “SIGUE”.
#
# La palabra “LA” debe estar en la posición (0.2, 0.8), con tamaño 50 y rotación 25, con alineación vertical y horizontal en el centro, y en una caja de estilo redondo, con color de borde y relleno #242fff y transparencia 0.7.
#
# La palabra “AVENTURA” debe estar en la posición (0.5, 0.55), con tamaño 50 y rotación -15, con alineación vertical y horizontal en el centro, y en una caja de estilo redondo, con color de borde y relleno #8a24ff y transparencia 0.7.
#
# La palabra “SIGUE” debe estar en la posición (0.8, 0.3), con tamaño 50 y rotación 10, con alineación vertical y horizontal en el centro, y en una caja de estilo redondo, con color de borde y relleno #24fff4 y transparencia 0.7.
#
# El tamaño de la figure global debe ser 10 x 8.

# %%
import matplotlib.pyplot as plt


plt.text(s='LA', x=0.2, y=0.8, size=50, rotation=25, va='center', ha='center',
         bbox=dict(boxstyle='round', ec='#242FFF', fc='#242FFF', alpha=0.7))

plt.text(s='AVENTURA', x=0.5, y=0.55, size=50, rotation=-15, va='center', ha='center',
         bbox=dict(boxstyle='round', ec='#8A24FF', fc='#8A24FF', alpha=0.7))

plt.text(s='SIGUE', x=0.8, y=0.3, size=50, rotation=10, va='center', ha='center',
         bbox=dict(boxstyle='round', ec='#24FFF4', fc='#24FFF4', alpha=0.7))

plt.figure(num=1, figsize=(10, 8))
plt.show()

# %% [markdown]
# ![Figure_10.png](data:image/png;base64,...)
